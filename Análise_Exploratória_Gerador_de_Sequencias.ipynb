# %% [markdown]
# # Apresentação
#
# Neste notebook, é apresentado a construção de um gerador de sequência e o treinamento do modelo CNN. O gerador de sequência é útil para treinamento de modelos com grandes conjuntos de dados e uma das vantagens de utiliza-lo é a redução de memória ao carregar os dados, evitando que estoure, pois ao invés de carregar tudo de uma vez, apenas carrega em lotes ou "batches". Abaixo há mais detalhes a respeito da Implementação.
#
# Obs: o conjunto de dados utilizado é o mesmo conjunto disponibilizado no drive da turma durante a aula.

# %% [markdown]
# ## Sumário
# - Carregamento do conjunto de dados com Google Drive
# - Importação de Bibliotecas
# - Implementação e execução do gerador de sequências
# - Implementação do modelo de rede neural convolucional(CNN)
# - Compilação
# - Treinamento

# %% [markdown]
# ### Carregamento do conjunto de dados com Google Drive
#
# Primeiramente fazemos o quesito padrão e essencial para fazer o modelo funcionar, ou seja, é carregar o conjunto de dados que vamos utilizar durante todo o processo. Por isso, conectamos com o Google Drive para posteriormente indicar o diretório onde as imagens utilizadas e classificadas por categoria se encontram.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importação de bibliotecas

# %% [markdown]
# Após fazer a conexão com o Google Drive, é necessário fazer as devidas importações ou bibliotecas que serão utilizadas durante o processo de rodagem do modelo.

# %%
import tensorflow as tf  # Biblioteca usada para criar e treinar redes neurais
from keras.utils import to_categorical, Sequence  # Importa funções utilitárias
from glob import glob  # Importa a função 'glob' para encontrar todos os caminhos que correspondem a um padrão
import numpy as np  # Importa a biblioteca numpy para manipulação de arrays
from keras.models import Sequential  # Importa o modelo 'Sequential' do Keras, uma pilha linear de camadas
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout  # Importa várias camadas do Keras usadas em redes neurais
from skimage.color import rgb2gray  # Importa função para converter imagens RGB em escala de cinza
from tensorflow.keras.models import Sequential  # Importa novamente o modelo 'Sequential', desta vez diretamente do tensorflow.keras
from tensorflow.keras.layers import DepthwiseConv2D, Conv2D  # Importa camadas de convolução, incluindo a DepthwiseConv2D, do tensorflow.keras
from tensorflow.keras.optimizers import Adam  # Importa o otimizador Adam do tensorflow.keras

# %% [markdown]
# ### Implementação e execução do gerador de sequências

# %% [markdown]
# Inicia-se atribuindo uma classe específica apenas para o gerador de sequência denominado "GeradorSequencias".
#
# - Definindo o "__ init __", para a inicialização, inserimos:
#
# 1. A entrada que listará o caminho do arquivo;
# 2. A saída que recebe saídas, ou seja, lista os identificadores ou labels para cada entrada;
# 3. Definimos o "batch_size" ou tamanho do lote que é o número de amostras por lote, o tamanho do lote é responsável por determinar quantas entradas e saídas são processadas durante o treino.
#
# Após inserir o "__ init __", partimos para o cálculo do número de lotes representado pela função "__ len __".
#
# - Função "__ len __":
# Essa função é responsável por determinar quantos lotes podem ser formados com o conjunto de dados total a partir da divisão do número total de entradas pelo tamanho do lote. Conforme estabelece os cálculos, também determina quantas vezes o "get item" a seguir precisa ser chamado por época.
#
# - Uso do ""__ getitem __":
# Este é chamado pelo Keras durante o treino e obtém o lote específico de acordo com o índice.
#
# - Cálculo de índices:
# Determina os índices das amostras que serão incluídas no lote que funciona com duas direções o qual é esquerda e direita, a esquerda é calculada como o índice de início do lote, e direita é o índice final, que não ultrapassa o número total de entradas.
#
# - Seleção de lote: As entradas e saídas para o lote são selecionadas usando os índices calculados. Essas amostras são as que serão carregadas e processadas.
#
# - Processamento de entradas x, y: o x carrega as imagens pelos caminhos em batch_entradas, converte para um array np e normaliza os valores de pixel para 0 e 1 e divide por 255. Já o y converte os rótulos especificados em batch_saidas para representações categóricas usando to_categorical. O número 14 indica que existem 14 classes possíveis.
#
# Durante o treinamento, o Keras chama o método __getitem__ repetidamente para obter cada lote e usa esses dados para treinar o modelo. O uso de Sequence garante que o modelo possa ser treinado em múltiplas threads e que a ordem dos dados seja mantida.
#
#
# Obs: tal código foi feito juntamente com o professor durante a instrução

# %%
class GeradorSequencias(Sequence):

    def __init__(self, entradas, saidas, batch_size):
        self.entradas = entradas  # Armazena os caminhos das imagens que serão usadas como entradas.
        self.saidas = saidas  # Armazena os caminhos das imagens ou labels que serão usadas como saídas (target).
        self.batch_size = batch_size  # Define o tamanho do lote (quantidade de amostras por lote).

    def __len__(self):
        # Define o número total de lotes por época.
        return len(self.entradas) // self.batch_size  # Calcula quantos lotes completos existem no dataset.

    def __getitem__(self, id):
        # Retorna um lote completo de entradas e saídas, dado um índice de lote específico.
        esquerda = id * self.batch_size  # Calcula o índice inicial do lote.
        direita = min(esquerda + self.batch_size, len(self.entradas))  # Calcula o índice final do lote; evita ultrapassar o tamanho da lista.
        batch_entradas = self.entradas[esquerda:direita]  # Seleciona o subconjunto das entradas para o lote atual.
        batch_saidas = self.saidas[esquerda:direita]  # Seleciona o subconjunto das saídas para o lote atual.

        x = np.array([img.imread(caminho)/255 for caminho in batch_entradas])  # Carrega as imagens das entradas, normaliza e converte para um array numpy.
        y = np.array([to_categorical(int(caminho.split('/')[-2]), 14) for caminho in batch_saidas])  # Processa as saídas para formato categórico.

        return x, y  # Retorna o lote de entradas e saídas processadas.

# %% [markdown]
# Abaixo há o caminho onde recebe todas as imagens presentes nos diretórios e subdiretórios.

# %%
caminhos = glob('/content/drive/MyDrive/Aula08052024/imagens/*/*.jpg')

# %% [markdown]
# Embaralhamento aleatório dos elementos da lista "caminhos" para evitar viés de ordem.

# %%
np.random.shuffle(caminhos) # embaralha aleatoriamente a lista 'caminhos' para garantir que a ordem dos dados seja aleatória antes de iniciar o treinamento de um modelo,
# o que pode ajuda na generalização do modelo
len(caminhos)
# Out:
# 1400

# %% [markdown]
# Cria uma instância da classe GeradorSequencias com três argumentos "caminho", "caminhos" e "5". O 5 representa que cada batch de dados conterá 5 imagens(cinco entradas e cinco saída correspondentes)

# %%
# Esta linha cria uma instância da classe 'GeradorSequencias', usando 'caminhos' tanto para as entradas quanto para as saídas, com um tamanho de lote de 5.
# Cada lote gerado pela sequência conterá 5 elementos
sequencia = GeradorSequencias(caminhos, caminhos, 5)

# %% [markdown]
# Ao atribuir o "sequencia.__len__()", será retornado o número total de batches. Esses batches é o qe o gerador cria e é calculado dividindo o número total de entradas pelo "batch_size"
#
#
# OBs: como a divisão é inteira, caso houver entradas que não completam um batch inteiro, elas não são contabilizadas.

# %%
sequencia.__len__()
# Out:
# 280

# %% [markdown]
# Nesta célula, o código calcula o índice do primeiro item do batch a esquerda e o índice do item logo após o último item do batch que é a direita.
#
# Dentro do método, o x normaliza as imagens(divide os valores dos pixels por 255 para fazer a conversão dos valores para o intervalo 0 e 1, enquanto y converte as saídas para vetores categóricos. Inserimos um ".shape" para obter o tamanho.

# %%
# Esta linha acessa o primeiro lote de dados gerado pela instância e obtém o shape do array numpy contendo as imagens de entrada
sequencia.__getitem__(0)[0].shape
# Out:
# (5, 768, 1024, 3)

# %% [markdown]
# # Implementação do modelo CNN

# %% [markdown]
# - DepthwiseConv2D:
# É uma camada que opera separadamente em cada canal de entrada e foi implementada após ter alguns erros com TensorFlow.
#   - kernel_size=(3, 3) define o tamanho do filtro como 3x3;
#   - A ativação relu é usada para introduzir não-linearidades no modelo;
#   - padding='same' garante que o tamanho da saída seja o mesmo que o da entrada
#   - input_shape=(768, 1024, 3) define a forma da entrada do modelo, que neste caso são imagens de 768x1024 pixels com 3 canais de cor (RGB).
#
# - Conv2D(16, kernel_size=(1, 1)):
# Essa camada convolucional  reduz a profundidade do mapa de características. Aqui, 16 filtros são aplicados com um tamanho de kernel de 1x1 para reduzir a dimensionalidade entre camadas convolucionais pesadas.
#
# - MaxPooling2D(pool_size=(3, 3)):
# Essa camada realiza uma operação de max pooling com uma janela de 3x3, o que reduz a dimensão espacial dos mapas de características pela seleção do valor máximo dentro de cada janela de pooling.
#
# - Conv2D(32, kernel_size=(3, 3)): Uma outra camada convolucional que agora aplica 32 filtros de tamanho 3x3, permitindo ao modelo aprender características mais complexas.
#
# - Flatten():
# Esta camada achata os mapas de características multidimensionais em um vetor unidimensional, permitindo que os dados sejam alimentados em camadas totalmente conectadas.
#
# - Dense(60, activation='relu'):
# É uma camada totalmente conectada com 60 neurônios
#
# - Dense(14, activation='softmax'): A camada final é uma camada densa com 14 neurônios, cada um correspondendo a uma classe de saída. A função de ativação softmax é usada para calcular a distribuição de probabilidade sobre as 14 classes presentes.

# %%
modelo = Sequential([
    # Adiciona uma camada de convolução em profundidade, que aplica um único filtro por canal de entrada
    DepthwiseConv2D(kernel_size=(3, 3), activation='relu', padding='same', input_shape=(768, 1024, 3)),
    # Adiciona uma camada convolucional que compacta as características aprendidas anteriormente em 16 mapas de características distintos
    Conv2D(16, kernel_size=(1, 1), activation='relu', padding='same'),
    # Adiciona uma camada de pooling máximo com um filtro de 3x3 para reduzir as dimensões espaciais dos mapas
    MaxPooling2D(pool_size=(3, 3)),
    # Adiciona outra camada convolucional para aprender características mais complexas com 32 filtros, mantendo o tamanho da saída igual ao da entrada
    Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same',),
    # Adiciona outra camada de pooling máximo para continuar a redução dimensional e aumentar a abstração das características
    MaxPooling2D(pool_size=(3, 3)),
    # Achata os mapas de características multidimensionais em um vetor unidimensional para ser possível a entrada em camadas densas
    Flatten(),
    # Adiciona uma camada densa (totalmente conectada)
    Dense(60, activation='relu'),
    # Adiciona a última camada densa com 14 neurônios, um para cada classe.
    Dense(14, activation='softmax')
])
# Out:
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0

# %% [markdown]
# # Efetuando a compilação do modelo

# %% [markdown]
# Na compilação atribuímos o tipo de função de perda, otimizador e métricas
#
# - Função de Perda:
# A função de perda "categorical_crossentropy" calcula a diferença entre as previsões do modelo e os rótulos no treinamento. Para tarefas de classificação multiclasse, onde cada etiqueta é um vetor de probabilidades(por isso uso da ativação softmax), utiliza-se a entropia cruzada como uma potencial opção. Esta função de perda seve pra penalizar previsões longes dos valores reais
#
#
# - optimizer=Adam():
# A escolha do adam se deve pelo uso semelhante no projeto do grupo, mas também porque o Adam é um otimizador baseado em gradientes que ajusta os pesos da rede durante o treinamento e não precisa de tanta configuração manual dos hiperparâmetros. Ele é capaz de ajustar a taxa de aprendizagem de forma adaptativa para diferentes parâmetros.
#
# - metrics=['accuracy']:
# É usada para monitorar o desempenho do modelo durante o treinamento e a validação. Neste caso, a acurácia é a fração de imagens corretamente classificadas em relação ao total de imagens.

# %%
modelo.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
# Out:
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0

# %% [markdown]
# # Treino do modelo

# %%
#TREINAR MODELO A PARTIR DO OBJETO GERADOR DE SEQUENCIAS

# %% [markdown]
# Aqui trata-se do treinamento do modelo. O gerador fornece batches de dados de entrada e saída como imagens ao modelo em cada etapa do treinamento.
#
#  O "epochs" define o número de vezes que o modelo passará pelo conjunto de dados completo. O epochs com valor 5 siginifica que o ciclo de treinamento completo, passando por todos os dados, será repetido cinco vezes.

# %%
modelo.fit(sequencia, epochs= 5)
# Out:
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AnonymousIteratorV3 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AnonymousIteratorV3 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Epoch 1/5
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#   1/280 [..............................] - ETA: 28:06 - loss: 2.6413 - accuracy: 0.0000e+00Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#   2/280 [..............................] - ETA: 19:07 - loss: 5.3828 - accuracy: 0.0000e+00Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#   3/280 [..............................] - ETA: 18:15 - loss: 5.3953 - accuracy: 0.0667    Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#   4/280 [..............................] - ETA: 20:00 - loss: 5.9628 - accuracy: 0.0500Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#   5/280 [..............................] - ETA: 23:06 - loss: 5.5032 - accuracy: 0.0800Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#   6/280 [..............................] - ETA: 24:51 - loss: 5.3264 - accuracy: 0.0667Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#   7/280 [..............................] - ETA: 22:55 - loss: 5.0584 - accuracy: 0.0857Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#   8/280 [..............................] - ETA: 21:27 - loss: 4.7768 - accuracy: 0.1000Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#   9/280 [..............................] - ETA: 20:36 - loss: 4.5670 - accuracy: 0.1111Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  10/280 [>.............................] - ETA: 21:07 - loss: 4.3672 - accuracy: 0.1200Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  11/280 [>.............................] - ETA: 20:15 - loss: 4.2078 - accuracy: 0.1091Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  12/280 [>.............................] - ETA: 19:31 - loss: 4.0915 - accuracy: 0.1000Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  13/280 [>.............................] - ETA: 18:53 - loss: 3.9820 - accuracy: 0.0923Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  14/280 [>.............................] - ETA: 18:52 - loss: 3.8854 - accuracy: 0.0857Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  15/280 [>.............................] - ETA: 18:36 - loss: 3.8036 - accuracy: 0.0800Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  16/280 [>.............................] - ETA: 18:08 - loss: 3.7316 - accuracy: 0.0750Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  17/280 [>.............................] - ETA: 17:46 - loss: 3.6634 - accuracy: 0.0824Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  18/280 [>.............................] - ETA: 17:30 - loss: 3.5988 - accuracy: 0.1000Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  19/280 [=>............................] - ETA: 17:36 - loss: 3.5585 - accuracy: 0.0947Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  20/280 [=>............................] - ETA: 17:17 - loss: 3.5233 - accuracy: 0.0900Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  21/280 [=>............................] - ETA: 16:59 - loss: 3.4882 - accuracy: 0.0857Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  22/280 [=>............................] - ETA: 16:42 - loss: 3.4487 - accuracy: 0.0818Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  23/280 [=>............................] - ETA: 16:35 - loss: 3.4044 - accuracy: 0.0957Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  24/280 [=>............................] - ETA: 16:36 - loss: 3.3715 - accuracy: 0.0917Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  25/280 [=>............................] - ETA: 16:21 - loss: 3.3408 - accuracy: 0.0880Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  26/280 [=>............................] - ETA: 16:08 - loss: 3.3158 - accuracy: 0.0846Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  27/280 [=>............................] - ETA: 15:55 - loss: 3.2876 - accuracy: 0.0889Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  28/280 [==>...........................] - ETA: 15:56 - loss: 3.2657 - accuracy: 0.0857Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  29/280 [==>...........................] - ETA: 15:52 - loss: 3.2322 - accuracy: 0.0897Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  30/280 [==>...........................] - ETA: 15:41 - loss: 3.1959 - accuracy: 0.1000Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  31/280 [==>...........................] - ETA: 15:31 - loss: 3.1775 - accuracy: 0.0968Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  32/280 [==>...........................] - ETA: 15:23 - loss: 3.1616 - accuracy: 0.0938Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  33/280 [==>...........................] - ETA: 15:27 - loss: 3.1311 - accuracy: 0.0970Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  34/280 [==>...........................] - ETA: 15:17 - loss: 3.1082 - accuracy: 0.1000Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  35/280 [==>...........................] - ETA: 15:08 - loss: 3.0863 - accuracy: 0.0971Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  36/280 [==>...........................] - ETA: 14:58 - loss: 3.0586 - accuracy: 0.1000Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  37/280 [==>...........................] - ETA: 14:54 - loss: 3.0515 - accuracy: 0.0973Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  38/280 [===>..........................] - ETA: 14:55 - loss: 3.0416 - accuracy: 0.0947Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  39/280 [===>..........................] - ETA: 14:46 - loss: 3.0112 - accuracy: 0.0974Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  40/280 [===>..........................] - ETA: 14:38 - loss: 2.9946 - accuracy: 0.0950Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  41/280 [===>..........................] - ETA: 14:30 - loss: 2.9770 - accuracy: 0.0976Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  42/280 [===>..........................] - ETA: 14:28 - loss: 2.9606 - accuracy: 0.0952Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  43/280 [===>..........................] - ETA: 14:27 - loss: 2.9430 - accuracy: 0.0977Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  44/280 [===>..........................] - ETA: 14:19 - loss: 2.9141 - accuracy: 0.1045Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  45/280 [===>..........................] - ETA: 14:12 - loss: 2.8790 - accuracy: 0.1067Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  46/280 [===>..........................] - ETA: 14:04 - loss: 2.8617 - accuracy: 0.1087Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  47/280 [====>.........................] - ETA: 14:06 - loss: 2.8635 - accuracy: 0.1106Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  48/280 [====>.........................] - ETA: 14:02 - loss: 2.8559 - accuracy: 0.1125Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  49/280 [====>.........................] - ETA: 13:55 - loss: 2.8450 - accuracy: 0.1143Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  50/280 [====>.........................] - ETA: 13:48 - loss: 2.8275 - accuracy: 0.1160Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  51/280 [====>.........................] - ETA: 13:43 - loss: 2.8316 - accuracy: 0.1137Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  52/280 [====>.........................] - ETA: 13:44 - loss: 2.8145 - accuracy: 0.1192Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  53/280 [====>.........................] - ETA: 13:37 - loss: 2.7987 - accuracy: 0.1208Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  54/280 [====>.........................] - ETA: 13:31 - loss: 2.7940 - accuracy: 0.1185Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  55/280 [====>.........................] - ETA: 13:25 - loss: 2.7883 - accuracy: 0.1164Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  56/280 [=====>........................] - ETA: 13:22 - loss: 2.7769 - accuracy: 0.1179Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  57/280 [=====>........................] - ETA: 13:21 - loss: 2.7786 - accuracy: 0.1158Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  58/280 [=====>........................] - ETA: 13:15 - loss: 2.7686 - accuracy: 0.1172Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  59/280 [=====>........................] - ETA: 13:09 - loss: 2.7417 - accuracy: 0.1288Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  60/280 [=====>........................] - ETA: 13:03 - loss: 2.7245 - accuracy: 0.1333Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  61/280 [=====>........................] - ETA: 13:03 - loss: 2.7091 - accuracy: 0.1410Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  62/280 [=====>........................] - ETA: 12:59 - loss: 2.7013 - accuracy: 0.1387Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  63/280 [=====>........................] - ETA: 12:54 - loss: 2.6936 - accuracy: 0.1397Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  64/280 [=====>........................] - ETA: 12:48 - loss: 2.6880 - accuracy: 0.1406Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  65/280 [=====>........................] - ETA: 12:43 - loss: 2.6647 - accuracy: 0.1477Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  66/280 [======>.......................] - ETA: 12:43 - loss: 2.6513 - accuracy: 0.1515Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  67/280 [======>.......................] - ETA: 12:38 - loss: 2.6467 - accuracy: 0.1493Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  68/280 [======>.......................] - ETA: 12:32 - loss: 2.6499 - accuracy: 0.1471Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  69/280 [======>.......................] - ETA: 12:27 - loss: 2.6361 - accuracy: 0.1507Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  70/280 [======>.......................] - ETA: 12:23 - loss: 2.6279 - accuracy: 0.1543Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  71/280 [======>.......................] - ETA: 12:23 - loss: 2.6200 - accuracy: 0.1549Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  72/280 [======>.......................] - ETA: 12:17 - loss: 2.6142 - accuracy: 0.1556Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  73/280 [======>.......................] - ETA: 12:12 - loss: 2.6023 - accuracy: 0.1616Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  74/280 [======>.......................] - ETA: 12:07 - loss: 2.5926 - accuracy: 0.1649Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  75/280 [=======>......................] - ETA: 12:05 - loss: 2.5737 - accuracy: 0.1680Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  76/280 [=======>......................] - ETA: 12:02 - loss: 2.5678 - accuracy: 0.1684Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  77/280 [=======>......................] - ETA: 11:57 - loss: 2.5562 - accuracy: 0.1714Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  78/280 [=======>......................] - ETA: 11:52 - loss: 2.5451 - accuracy: 0.1744Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  79/280 [=======>......................] - ETA: 11:47 - loss: 2.5332 - accuracy: 0.1772Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  80/280 [=======>......................] - ETA: 11:46 - loss: 2.5236 - accuracy: 0.1775Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  81/280 [=======>......................] - ETA: 11:42 - loss: 2.5282 - accuracy: 0.1753Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  82/280 [=======>......................] - ETA: 11:38 - loss: 2.5124 - accuracy: 0.1780Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  83/280 [=======>......................] - ETA: 11:33 - loss: 2.5052 - accuracy: 0.1783Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  84/280 [========>.....................] - ETA: 11:28 - loss: 2.4955 - accuracy: 0.1833Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  85/280 [========>.....................] - ETA: 11:27 - loss: 2.4838 - accuracy: 0.1835Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  86/280 [========>.....................] - ETA: 11:23 - loss: 2.4733 - accuracy: 0.1884Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  87/280 [========>.....................] - ETA: 11:18 - loss: 2.4626 - accuracy: 0.1954Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  88/280 [========>.....................] - ETA: 11:13 - loss: 2.4586 - accuracy: 0.1955Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  89/280 [========>.....................] - ETA: 11:10 - loss: 2.4557 - accuracy: 0.1978Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  90/280 [========>.....................] - ETA: 11:09 - loss: 2.4530 - accuracy: 0.2000Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  91/280 [========>.....................] - ETA: 11:04 - loss: 2.4423 - accuracy: 0.2022Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  92/280 [========>.....................] - ETA: 10:59 - loss: 2.4380 - accuracy: 0.2043Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  93/280 [========>.....................] - ETA: 10:54 - loss: 2.4374 - accuracy: 0.2022Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  94/280 [=========>....................] - ETA: 10:52 - loss: 2.4342 - accuracy: 0.2021Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  95/280 [=========>....................] - ETA: 10:50 - loss: 2.4374 - accuracy: 0.2021Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  96/280 [=========>....................] - ETA: 10:45 - loss: 2.4286 - accuracy: 0.2083Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  97/280 [=========>....................] - ETA: 10:40 - loss: 2.4184 - accuracy: 0.2124Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  98/280 [=========>....................] - ETA: 10:36 - loss: 2.4187 - accuracy: 0.2102Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
#  99/280 [=========>....................] - ETA: 10:35 - loss: 2.4041 - accuracy: 0.2141Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 100/280 [=========>....................] - ETA: 10:31 - loss: 2.3928 - accuracy: 0.2160Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 101/280 [=========>....................] - ETA: 10:27 - loss: 2.3827 - accuracy: 0.2198Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 102/280 [=========>....................] - ETA: 10:22 - loss: 2.3784 - accuracy: 0.2216Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 103/280 [==========>...................] - ETA: 10:19 - loss: 2.3697 - accuracy: 0.2233Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 104/280 [==========>...................] - ETA: 10:17 - loss: 2.3672 - accuracy: 0.2250Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 105/280 [==========>...................] - ETA: 10:13 - loss: 2.3570 - accuracy: 0.2286Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 106/280 [==========>...................] - ETA: 10:08 - loss: 2.3502 - accuracy: 0.2302Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 107/280 [==========>...................] - ETA: 10:03 - loss: 2.3427 - accuracy: 0.2336Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 108/280 [==========>...................] - ETA: 10:01 - loss: 2.3350 - accuracy: 0.2370Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 109/280 [==========>...................] - ETA: 9:58 - loss: 2.3293 - accuracy: 0.2385 Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 110/280 [==========>...................] - ETA: 9:54 - loss: 2.3269 - accuracy: 0.2400Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 111/280 [==========>...................] - ETA: 9:50 - loss: 2.3249 - accuracy: 0.2378Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 112/280 [===========>..................] - ETA: 9:45 - loss: 2.3189 - accuracy: 0.2375Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 113/280 [===========>..................] - ETA: 9:44 - loss: 2.3134 - accuracy: 0.2389Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 114/280 [===========>..................] - ETA: 9:40 - loss: 2.3038 - accuracy: 0.2421Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 115/280 [===========>..................] - ETA: 9:35 - loss: 2.2929 - accuracy: 0.2470Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 116/280 [===========>..................] - ETA: 9:31 - loss: 2.2853 - accuracy: 0.2500Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 117/280 [===========>..................] - ETA: 9:28 - loss: 2.2773 - accuracy: 0.2547Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# ...
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 237/280 [========================>.....] - ETA: 2:24 - loss: 0.0482 - accuracy: 0.9899Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 238/280 [========================>.....] - ETA: 2:20 - loss: 0.0480 - accuracy: 0.9899Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 239/280 [========================>.....] - ETA: 2:17 - loss: 0.0478 - accuracy: 0.9900Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 240/280 [========================>.....] - ETA: 2:14 - loss: 0.0477 - accuracy: 0.9900Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 241/280 [========================>.....] - ETA: 2:10 - loss: 0.0476 - accuracy: 0.9900Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 242/280 [========================>.....] - ETA: 2:07 - loss: 0.0476 - accuracy: 0.9901Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 243/280 [=========================>....] - ETA: 2:04 - loss: 0.0478 - accuracy: 0.9901Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 244/280 [=========================>....] - ETA: 2:00 - loss: 0.0491 - accuracy: 0.9893Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 245/280 [=========================>....] - ETA: 1:57 - loss: 0.0489 - accuracy: 0.9894Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 246/280 [=========================>....] - ETA: 1:54 - loss: 0.0487 - accuracy: 0.9894Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 247/280 [=========================>....] - ETA: 1:50 - loss: 0.0485 - accuracy: 0.9895Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 248/280 [=========================>....] - ETA: 1:47 - loss: 0.0483 - accuracy: 0.9895Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 249/280 [=========================>....] - ETA: 1:44 - loss: 0.0483 - accuracy: 0.9896Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 250/280 [=========================>....] - ETA: 1:40 - loss: 0.0481 - accuracy: 0.9896Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 251/280 [=========================>....] - ETA: 1:37 - loss: 0.0479 - accuracy: 0.9896Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 252/280 [==========================>...] - ETA: 1:33 - loss: 0.0477 - accuracy: 0.9897Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 253/280 [==========================>...] - ETA: 1:30 - loss: 0.0480 - accuracy: 0.9897Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 254/280 [==========================>...] - ETA: 1:27 - loss: 0.0479 - accuracy: 0.9898Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 255/280 [==========================>...] - ETA: 1:23 - loss: 0.0502 - accuracy: 0.9890Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 256/280 [==========================>...] - ETA: 1:20 - loss: 0.0501 - accuracy: 0.9891Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 257/280 [==========================>...] - ETA: 1:17 - loss: 0.0500 - accuracy: 0.9891Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 258/280 [==========================>...] - ETA: 1:13 - loss: 0.0498 - accuracy: 0.9891Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 259/280 [==========================>...] - ETA: 1:10 - loss: 0.0496 - accuracy: 0.9892Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 260/280 [==========================>...] - ETA: 1:07 - loss: 0.0496 - accuracy: 0.9892Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 261/280 [==========================>...] - ETA: 1:03 - loss: 0.0496 - accuracy: 0.9893Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 262/280 [===========================>..] - ETA: 1:00 - loss: 0.0494 - accuracy: 0.9893Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 263/280 [===========================>..] - ETA: 57s - loss: 0.0513 - accuracy: 0.9886 Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 264/280 [===========================>..] - ETA: 53s - loss: 0.0556 - accuracy: 0.9871Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 265/280 [===========================>..] - ETA: 50s - loss: 0.0554 - accuracy: 0.9872Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 266/280 [===========================>..] - ETA: 46s - loss: 0.0560 - accuracy: 0.9865Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 267/280 [===========================>..] - ETA: 43s - loss: 0.0559 - accuracy: 0.9865Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 268/280 [===========================>..] - ETA: 40s - loss: 0.0557 - accuracy: 0.9866Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 269/280 [===========================>..] - ETA: 36s - loss: 0.0555 - accuracy: 0.9866Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 270/280 [===========================>..] - ETA: 33s - loss: 0.0574 - accuracy: 0.9859Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 271/280 [============================>.] - ETA: 30s - loss: 0.0572 - accuracy: 0.9860Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 272/280 [============================>.] - ETA: 26s - loss: 0.0575 - accuracy: 0.9853Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 273/280 [============================>.] - ETA: 23s - loss: 0.0573 - accuracy: 0.9853Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 274/280 [============================>.] - ETA: 20s - loss: 0.0572 - accuracy: 0.9854Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 275/280 [============================>.] - ETA: 16s - loss: 0.0583 - accuracy: 0.9847Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 276/280 [============================>.] - ETA: 13s - loss: 0.0588 - accuracy: 0.9848Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 277/280 [============================>.] - ETA: 10s - loss: 0.0591 - accuracy: 0.9848Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 278/280 [============================>.] - ETA: 6s - loss: 0.0609 - accuracy: 0.9842 Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 279/280 [============================>.] - ETA: 3s - loss: 0.0608 - accuracy: 0.9842Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_function_2732 in device /job:localhost/replica:0/task:0/device:CPU:0
# 280/280 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9843Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op DivNoNan in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op DivNoNan in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# 280/280 [==============================] - 940s 3s/step - loss: 0.0607 - accuracy: 0.9843

# %% [markdown]
# Após rodar otreinamento do modelo com a CPU, a acurácia obtida foi de 0.98 e a loss foi de 0.06.
